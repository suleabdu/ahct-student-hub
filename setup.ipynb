# %%
# !git add ./frontend/js/config.js
# !git commit -m "Update API_BASE_URL in config.js to deployed backend URL"
# !git push origin main
# Out:
# ...
# [main a67466c] Update API_BASE_URL in config.js to deployed backend URL
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/suleabdu/ahct-student-hub.git
#    72b20bf..a67466c  main -> main
